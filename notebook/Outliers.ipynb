# %%
import math
import numpy as np
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
from sklearn.model_selection import cross_val_score, KFold
from sklearn.metrics import r2_score
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from gensim.models.doc2vec import Doc2Vec, TaggedDocument
from sklearn.manifold import TSNE
import xgboost as xgb
from hyperopt import fmin, tpe, space_eval, hp, STATUS_OK, Trials
from keras.layers import Input, Dense, Dropout
from keras.models import Model
from keras import Sequential
from keras.regularizers import l1, l2
from numpy.random import default_rng
import matplotlib.lines as mlines
import pickle

# %matplotlib inline

# %%
df = pd.read_csv('2020.1 - sysarmy - Encuesta de remuneración salarial Argentina - Argentina.csv', skiprows=9)
df = df[df['Salario mensual BRUTO (en tu moneda local)'] < 1_000_000]
df = df[df['Años en la empresa actual'] < 40]
df = df[(df['Salario mensual BRUTO (en tu moneda local)'] >= 10_000) & (df['Salario mensual BRUTO (en tu moneda local)'] <= 1_000_000)]
df.head()
# Out:
#   Me identifico  Tengo Dónde estás trabajando  Años de experiencia  \
# 0        Hombre     40              Catamarca                 15.0
# 1         Mujer     35              Catamarca                 15.0
# 2        Hombre     39                  Chaco                 10.0
# 3        Hombre     42                  Chaco                 18.0
# 4        Hombre     29                  Chaco                  4.0
#
#    Años en la empresa actual  Años en el puesto actual ¿Gente a cargo?  \
# 0                        0.0                       0.0               0
# 1                       10.0                       3.0               5
# 2                        5.0                       5.0               6
# 3                        3.0                       3.0               0
# 4                        0.0                       0.0               1
#
#   Nivel de estudios alcanzado      Estado  \
# 0               Universitario  Completado
# 1                    Posgrado  Completado
# 2               Universitario  Incompleto
# 3               Universitario  Completado
# 4               Universitario  Completado
#
#                                    Carrera  ...  \
# 0  Licenciatura en Sistemas de Información  ...
# 1  Licenciatura en Sistemas de Información  ...
# 2    Ingeniería en Sistemas de Información  ...
# 3     Licenciatura en Análisis de Sistemas  ...
# 4                   Ingeniería Electrónica  ...
#
#   ¿Tenés algún tipo de discapacidad?  \
# 0                                NaN
# 1                                NaN
# 2                                NaN
# 3                                NaN
# 4                                NaN
#
#   ¿Sentís que esto te dificultó el conseguir trabajo?  \
# 0                                                NaN
# 1                                                 No
# 2                                                NaN
# 3                                                 No
# 4                                                NaN
#
#   ¿A qué eventos de tecnología asististe en el último año?  \
# 0                                                NaN
# 1                                                NaN
# 2                                           Ekoparty
# 3                                                NaN
# 4                        Pynea, Autodefensa digital
#
#   Cantidad de empleados                            Actividad principal  \
# 0               201-500                               Otras industrias
# 1                 11-50  Servicios / Consultoría de Software / Digital
# 2                 11-50  Servicios / Consultoría de Software / Digital
# 3                 11-50                    Producto basado en Software
# 4               201-500                               Otras industrias
#
#   ¿La recomendás como un buen lugar para trabajar?  \
# 0                                                6
# 1                                                5
# 2                                               10
# 3                                                5
# 4                                                8
#
#   ¿Cómo calificás las políticas de diversidad e inclusión?  \
# 0                                                  6
# 1                                                  8
# 2                                                 10
# 3                                                  3
# 4                                                  9
#
#   ¿A cuántos kilómetros de tu casa queda la oficina?  \
# 0                                                4.0
# 1                                                2.0
# 2                                                1.0
# 3                                               -1.0
# 4                                                5.0
#
#                                     Beneficios extra  \
# 0  Comidas pagas / subvencionadas, Estacionamient...
# 1                      Abono de celular y/o Internet
# 2  Capacitaciones y/o cursos, Clases de idiomas, ...
# 3  Horarios flexibles, Sueldo dolarizado, WFH (Tr...
# 4  Abono de celular y/o Internet, Comidas pagas /...
#
#   ¿Cuáles considerás que son las mejores empresas de IT para trabajar en este momento, en tu ciudad?
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
# [5 rows x 48 columns]

# %%
best = {'colsample_bytree': 0.7000000000000001, 'gamma': 0.8500000000000001, 'learning_rate': 0.025, 'max_depth': 16, 'min_child_weight': 15.0, 'n_estimators': 175, 'subsample': 0.8099576733552297}
regions_map = {
    'Ciudad Autónoma de Buenos Aires': 'AMBA',
    'GBA': 'AMBA',
    'Catamarca': 'NOA',
    'Chaco': 'NEA',
    'Chubut': 'Patagonia',
    'Corrientes': 'NEA',
    'Entre Ríos': 'NEA',
    'Formosa': 'NEA',
    'Jujuy': 'NOA',
    'La Pampa': 'Pampa',
    'La Rioja': 'NOA',
    'Mendoza': 'Cuyo',
    'Misiones': 'NEA',
    'Neuquén': 'Patagonia',
    'Río Negro': 'Patagonia',
    'Salta': 'NOA',
    'San Juan': 'Cuyo',
    'San Luis': 'Cuyo',
    'Santa Cruz': 'Patagonia',
    'Santa Fe': 'Pampa',
    'Santiago del Estero': 'NOA',
    'Tucumán': 'NOA',
    'Córdoba': 'Pampa',
    'Provincia de Buenos Aires': 'Pampa',
    'Tierra del Fuego': 'Patagonia',
}
class Model:
    def __init__(self, **params):
        self.regressor_ = xgb.XGBRegressor(**params)

    def get_params(self, deep=True):
        return self.regressor_.get_params(deep=deep)

    def set_params(self, **params):
        return self.regressor_.set_params(**params)
    
    def clean_words(self, field, value):
        value = value.replace('Microsoft Azure (Tables, CosmosDB, SQL, etc)', 'Microsoft Azure(TablesCosmosDBSQLetc)')
        value = value.replace('Snacks, golosinas, bebidas', 'snacks')
        value = value.replace('Descuentos varios (Clarín 365, Club La Nación, etc)', 'descuentos varios')
        value = value.replace('Sí, de forma particular', 'de forma particular')
        value = value.replace('Sí, los pagó un empleador', 'los pagó un empleador')
        value = value.replace('Sí, activa', 'activa')
        value = value.replace('Sí, pasiva', 'pasiva')
        return [self.clean_word(field, v) for v in value.split(',') if self.clean_word(field, v)]

    def clean_word(self, field, word):
        val = str(word).lower().strip().replace(".", "")
        if val in ('ninguno', 'ninguna', 'no', '0', 'etc)', 'nan'):
            return ''
        if field == 'Lenguajes de programación' and val == 'Microsoft Azure(TablesCosmosDBSQLetc)':
            return 'Microsoft Azure (Tables, CosmosDB, SQL, etc)'
        if field == '¿A qué eventos de tecnología asististe en el último año?' and val in ('pycon', 'pyconar'):
            return 'pyconar'
        if field == '¿A qué eventos de tecnología asististe en el último año?' and val in ('nodeconf', 'nodeconfar'):
            return 'nodeconfar'
        if field == '¿A qué eventos de tecnología asististe en el último año?' and val in ('meetup', 'meetups'):
            return 'meetups'
        if field == '¿A qué eventos de tecnología asististe en el último año?':
            return val.replace(' ', '')
        if field == 'Beneficios extra' and val == 'snacks':
            return 'snacks, golosinas, bebidas'
        if field == 'Beneficios extra' and val == 'descuentos varios':
            return 'descuentos varios (clarín 365, club la nación, etc)'
        return val

    def row_to_words(self, row):
        return [
            f'{key}={row.fillna("")[key]}'
            for key
            in (
                'Me identifico',
                'Nivel de estudios alcanzado',
                'Universidad',
                'Estado',
                'Carrera',
                '¿Contribuís a proyectos open source?',
                '¿Programás como hobbie?',
                'Trabajo de',
                '¿Qué SO usás en tu laptop/PC para trabajar?',
                '¿Y en tu celular?',
                'Tipo de contrato',
                'Orientación sexual',
                'Cantidad de empleados',
                'Actividad principal',
            )
        ] + [
            f'{k}={v}' for k in (
                '¿Tenés guardias?',
                'Realizaste cursos de especialización',
                '¿A qué eventos de tecnología asististe en el último año?',
                'Beneficios extra',
                'Plataformas',
                'Lenguajes de programación',
                'Frameworks, herramientas y librerías',
                'Bases de datos',
                'QA / Testing',
                'IDEs',
                'Lenguajes de programación'
            ) for v in self.clean_words(k, row.fillna('')[k])
        ] + [
            f'region={regions_map[row["Dónde estás trabajando"]]}'
        ]

    def encode_row(self, row):
        ws = self.row_to_words(row)
        return pd.Series([w in ws for w in self.valid_words_] + [
            row['¿Gente a cargo?'],
            row['Años de experiencia'],
            row['Tengo'],
        ])

    def fit(self, X, y):
        counts = {}
        for i in range(X.shape[0]):
            for word in self.row_to_words(X.iloc[i]):
                counts[word] = counts.get(word, 0) + 1
        self.valid_words_ = [word for word, c in counts.items() if c > 0.01*X.shape[0]]
        self.regressor_.fit(X.apply(self.encode_row, axis=1).astype(float), y)
        return self
   
    def predict(self, X):
        return self.regressor_.predict(X.apply(self.encode_row, axis=1).astype(float))
    
    def score(self, X, y):
        return r2_score(y, self.predict(X))

# %%
kf = KFold(n_splits=5, shuffle=True, random_state=99)
kf_models = []
for train_index, test_index in kf.split(df):
    model = Model().fit(df.iloc[train_index], df.iloc[train_index]['Salario mensual BRUTO (en tu moneda local)'])
    df.loc[df.index[test_index], 'e(salary)'] = model.predict(df.iloc[test_index])
    kf_models.append(model)

# %%
with open('.kf-cache', 'wb') as f:
    pickle.dump([kf, kf_models], f)

# %%
df['pifie'] = ((df['Salario mensual BRUTO (en tu moneda local)'] - df['e(salary)']).apply(np.abs) / df['Salario mensual BRUTO (en tu moneda local)'])

# %%
df.sort_values(by='pifie').tail().T
# Out:
#                                                                                                  2012  \
# Me identifico                                                                                  Hombre
# Tengo                                                                                              29
# Dónde estás trabajando                                                Ciudad Autónoma de Buenos Aires
# Años de experiencia                                                                                 5
# Años en la empresa actual                                                                           5
# Años en el puesto actual                                                                            3
# ¿Gente a cargo?                                                                                     0
# Nivel de estudios alcanzado                                                             Universitario
# Estado                                                                                     Completado
# Carrera                                                     Licenciatura en Ciencias dela Computación
# Universidad                                                        UNS - Universidad Nacional del Sur
# Realizaste cursos de especialización                                                               No
# ¿Contribuís a proyectos open source?                                                               No
# ¿Programás como hobbie?                                                                            Sí
# Trabajo de                                                                                  Developer
# Plataformas                                                                     Azure, Windows Server
# Lenguajes de programación                                                               .NET, C++, C#
# Frameworks, herramientas y librerías                                                        .NET Core
# Bases de datos                                                                                  MSSQL
# QA / Testing                                                                                      NaN
# IDEs                                                                                    Visual Studio
# ¿Qué SO usás en tu laptop/PC para trabajar?                                                   Windows
# ¿Y en tu celular?                                                                             Android
# ¿Tenés guardias?                                                                                   No
# Cuánto cobrás por guardia                                                                           0
# ¿Porcentaje, bruto o neto?                                                    Porcentaje de mi sueldo
# Tipo de contrato                                                                            Full-Time
# Salario mensual BRUTO (en tu moneda local)                                                      11500
# Salario mensual NETO (en tu moneda local)                                                       90000
# ¿Qué tan conforme estás con tu sueldo?                                                              3
# Cómo creés que está tu sueldo con respecto al ú...                                                  3
# Recibís algún tipo de bono                                                         Menos de un sueldo
# A qué está atado el bono                                                        Mix de las anteriores
# ¿Tuviste ajustes por inflación en 2019?                                                          Tres
# ¿De qué % fue el ajuste total?                                                                     40
# ¿En qué mes fue el último ajuste?                                                                  12
# ¿Sufriste o presenciaste situaciones de violenc...                                              Jamás
# Orientación sexual                                                                       Heterosexual
# ¿Tenés algún tipo de discapacidad?                                                                NaN
# ¿Sentís que esto te dificultó el conseguir trab...                                                 No
# ¿A qué eventos de tecnología asististe en el úl...                               nerdear.la, .netconf
# Cantidad de empleados                                                                       2001-5000
# Actividad principal                                                                  Otras industrias
# ¿La recomendás como un buen lugar para trabajar?                                                    7
# ¿Cómo calificás las políticas de diversidad e i...                                                  8
# ¿A cuántos kilómetros de tu casa queda la oficina?                                                  4
# Beneficios extra                                    Capacitaciones y/o cursos, Clases de idiomas, ...
# ¿Cuáles considerás que son las mejores empresas...                                                NaN
# e(salary)                                                                                      120452
# pifie                                                                                         9.47405
#
#                                                                                                  1755  \
# Me identifico                                                                                  Hombre
# Tengo                                                                                              40
# Dónde estás trabajando                                                Ciudad Autónoma de Buenos Aires
# Años de experiencia                                                                                17
# Años en la empresa actual                                                                           0
# Años en el puesto actual                                                                           10
# ¿Gente a cargo?                                                                                     0
# Nivel de estudios alcanzado                                                             Universitario
# Estado                                                                                       En curso
# Carrera                                                                   Licenciatura en Informática
# Universidad                                                                      Universidad Siglo 21
# Realizaste cursos de especialización                Sí, de forma particular, Sí, los pagó un emple...
# ¿Contribuís a proyectos open source?                                                               No
# ¿Programás como hobbie?                                                                            Sí
# Trabajo de                                                                                  Developer
# Plataformas                                                                                       NaN
# Lenguajes de programación                                                                         NaN
# Frameworks, herramientas y librerías                                                              NaN
# Bases de datos                                                                                    NaN
# QA / Testing                                                                                      NaN
# IDEs                                                                                              NaN
# ¿Qué SO usás en tu laptop/PC para trabajar?                                                 GNU/Linux
# ¿Y en tu celular?                                                                             Android
# ¿Tenés guardias?                                                                                   No
# Cuánto cobrás por guardia                                                                           0
# ¿Porcentaje, bruto o neto?                                                                      Bruto
# Tipo de contrato                                                                            Full-Time
# Salario mensual BRUTO (en tu moneda local)                                                      13000
# Salario mensual NETO (en tu moneda local)                                                       91000
# ¿Qué tan conforme estás con tu sueldo?                                                              2
# Cómo creés que está tu sueldo con respecto al ú...                                                  2
# Recibís algún tipo de bono                                                                         No
# A qué está atado el bono                                                               No recibo bono
# ¿Tuviste ajustes por inflación en 2019?                                                            No
# ¿De qué % fue el ajuste total?                                                                      0
# ¿En qué mes fue el último ajuste?                                                                   0
# ¿Sufriste o presenciaste situaciones de violenc...                                              Jamás
# Orientación sexual                                                                       Heterosexual
# ¿Tenés algún tipo de discapacidad?                                                                NaN
# ¿Sentís que esto te dificultó el conseguir trab...                                                NaN
# ¿A qué eventos de tecnología asististe en el úl...                                          nerdearla
# Cantidad de empleados                                                                      5001-10000
# Actividad principal                                     Servicios / Consultoría de Software / Digital
# ¿La recomendás como un buen lugar para trabajar?                                                    7
# ¿Cómo calificás las políticas de diversidad e i...                                                  7
# ¿A cuántos kilómetros de tu casa queda la oficina?                                                 28
# Beneficios extra                                    Capacitaciones y/o cursos, Clases de idiomas, ...
# ¿Cuáles considerás que son las mejores empresas...                                                NaN
# e(salary)                                                                                      138877
# pifie                                                                                         9.68287
#
#                                                                                                  2688  \
# Me identifico                                                                                  Hombre
# Tengo                                                                                              37
# Dónde estás trabajando                                                Ciudad Autónoma de Buenos Aires
# Años de experiencia                                                                                10
# Años en la empresa actual                                                                           6
# Años en el puesto actual                                                                            6
# ¿Gente a cargo?                                                                                     0
# Nivel de estudios alcanzado                                                             Universitario
# Estado                                                                                     Completado
# Carrera                                                          Licenciatura en Análisis de Sistemas
# Universidad                                                           USAL - Universidad del Salvador
# Realizaste cursos de especialización                Sí, de forma particular, Sí, los pagó un emple...
# ¿Contribuís a proyectos open source?                                                               Sí
# ¿Programás como hobbie?                                                                            No
# Trabajo de                                                                                  Developer
# Plataformas                                                                                     Linux
# Lenguajes de programación                                                     Javascript, PHP, Python
# Frameworks, herramientas y librerías                                                           jQuery
# Bases de datos                                                                MongoDB, Percona Server
# QA / Testing                                                                                      NaN
# IDEs                                                                                              Vim
# ¿Qué SO usás en tu laptop/PC para trabajar?                                                 GNU/Linux
# ¿Y en tu celular?                                                                             Android
# ¿Tenés guardias?                                                                                   No
# Cuánto cobrás por guardia                                                                           0
# ¿Porcentaje, bruto o neto?                                                    Porcentaje de mi sueldo
# Tipo de contrato                                                                            Full-Time
# Salario mensual BRUTO (en tu moneda local)                                                      10100
# Salario mensual NETO (en tu moneda local)                                                       90000
# ¿Qué tan conforme estás con tu sueldo?                                                              3
# Cómo creés que está tu sueldo con respecto al ú...                                                  3
# Recibís algún tipo de bono                                                      De uno a tres sueldos
# A qué está atado el bono                                                   Performance de la compañía
# ¿Tuviste ajustes por inflación en 2019?                                                          Tres
# ¿De qué % fue el ajuste total?                                                                     45
# ¿En qué mes fue el último ajuste?                                                                  10
# ¿Sufriste o presenciaste situaciones de violenc...                             En un trabajo anterior
# Orientación sexual                                                                       Heterosexual
# ¿Tenés algún tipo de discapacidad?                                                             Visual
# ¿Sentís que esto te dificultó el conseguir trab...                                                 No
# ¿A qué eventos de tecnología asististe en el úl...                                            Pyconar
# Cantidad de empleados                                                                          10001+
# Actividad principal                                                       Producto basado en Software
# ¿La recomendás como un buen lugar para trabajar?                                                    7
# ¿Cómo calificás las políticas de diversidad e i...                                                  8
# ¿A cuántos kilómetros de tu casa queda la oficina?                                                  2
# Beneficios extra                                    Clases de idiomas, Horarios flexibles, Vacacio...
# ¿Cuáles considerás que son las mejores empresas...                                                NaN
# e(salary)                                                                                      117199
# pifie                                                                                         10.6038
#
#                                                                                                  5444  \
# Me identifico                                                                                  Hombre
# Tengo                                                                                              36
# Dónde estás trabajando                                                      Provincia de Buenos Aires
# Años de experiencia                                                                                 6
# Años en la empresa actual                                                                           2
# Años en el puesto actual                                                                            2
# ¿Gente a cargo?                                                                                     0
# Nivel de estudios alcanzado                                                                  Posgrado
# Estado                                                                                       En curso
# Carrera                                                                   Licenciatura en Informática
# Universidad                                                   UNLP - Universidad Nacional de La Plata
# Realizaste cursos de especialización                                          Sí, de forma particular
# ¿Contribuís a proyectos open source?                                                               No
# ¿Programás como hobbie?                                                                            Sí
# Trabajo de                                                                                  Developer
# Plataformas                                                                             Docker, Linux
# Lenguajes de programación                                                          Javascript, Python
# Frameworks, herramientas y librerías                                                         React.js
# Bases de datos                                                                             PostgreSQL
# QA / Testing                                                                            Jest, Postman
# IDEs                                                                                    Visual Studio
# ¿Qué SO usás en tu laptop/PC para trabajar?                                                   Windows
# ¿Y en tu celular?                                                                             Android
# ¿Tenés guardias?                                                                                   No
# Cuánto cobrás por guardia                                                                           0
# ¿Porcentaje, bruto o neto?                                                                      Bruto
# Tipo de contrato                                                                            Full-Time
# Salario mensual BRUTO (en tu moneda local)                                                      10000
# Salario mensual NETO (en tu moneda local)                                                       75000
# ¿Qué tan conforme estás con tu sueldo?                                                              3
# Cómo creés que está tu sueldo con respecto al ú...                                                  3
# Recibís algún tipo de bono                                                                         No
# A qué está atado el bono                                                               No recibo bono
# ¿Tuviste ajustes por inflación en 2019?                                                   Más de tres
# ¿De qué % fue el ajuste total?                                                                     60
# ¿En qué mes fue el último ajuste?                                                                  12
# ¿Sufriste o presenciaste situaciones de violenc...                             En un trabajo anterior
# Orientación sexual                                                                       Heterosexual
# ¿Tenés algún tipo de discapacidad?                                                                NaN
# ¿Sentís que esto te dificultó el conseguir trab...                                                 No
# ¿A qué eventos de tecnología asististe en el úl...                                                NaN
# Cantidad de empleados                                                                           11-50
# Actividad principal                                                       Producto basado en Software
# ¿La recomendás como un buen lugar para trabajar?                                                    9
# ¿Cómo calificás las políticas de diversidad e i...                                                  9
# ¿A cuántos kilómetros de tu casa queda la oficina?                                                2.5
# Beneficios extra                                    Abono de celular y/o Internet, Comidas pagas /...
# ¿Cuáles considerás que son las mejores empresas...                                                NaN
# e(salary)                                                                                      118029
# pifie                                                                                         10.8029
#
#                                                                                                  605
# Me identifico                                                                                  Hombre
# Tengo                                                                                              50
# Dónde estás trabajando                                                Ciudad Autónoma de Buenos Aires
# Años de experiencia                                                                                25
# Años en la empresa actual                                                                           8
# Años en el puesto actual                                                                            8
# ¿Gente a cargo?                                                                                     0
# Nivel de estudios alcanzado                                                             Universitario
# Estado                                                                                       En curso
# Carrera                                                                          Analista de Sistemas
# Universidad                                                                  UK - Universidad Kennedy
# Realizaste cursos de especialización                                        Sí, los pagó un empleador
# ¿Contribuís a proyectos open source?                                                               No
# ¿Programás como hobbie?                                                                            No
# Trabajo de                                                                                        DBA
# Plataformas                                             Amazon Web Services, Linux, OpenStack, VMWare
# Lenguajes de programación                                                             Bash/Shell, SQL
# Frameworks, herramientas y librerías                                                              NaN
# Bases de datos                                      Cassandra, MySQL, Oracle, Percona XtraBackup, ...
# QA / Testing                                                                                      NaN
# IDEs                                                                                              NaN
# ¿Qué SO usás en tu laptop/PC para trabajar?                                                     macOS
# ¿Y en tu celular?                                                                                 iOS
# ¿Tenés guardias?                                                                           Sí, activa
# Cuánto cobrás por guardia                                                                           0
# ¿Porcentaje, bruto o neto?                                                    Porcentaje de mi sueldo
# Tipo de contrato                                                                            Full-Time
# Salario mensual BRUTO (en tu moneda local)                                                      13000
# Salario mensual NETO (en tu moneda local)                                                       98000
# ¿Qué tan conforme estás con tu sueldo?                                                              2
# Cómo creés que está tu sueldo con respecto al ú...                                                  1
# Recibís algún tipo de bono                                                      De uno a tres sueldos
# A qué está atado el bono                                                                       sarasa
# ¿Tuviste ajustes por inflación en 2019?                                                           Dos
# ¿De qué % fue el ajuste total?                                                                     30
# ¿En qué mes fue el último ajuste?                                                                  11
# ¿Sufriste o presenciaste situaciones de violenc...                                              Jamás
# Orientación sexual                                                                       Heterosexual
# ¿Tenés algún tipo de discapacidad?                                                                NaN
# ¿Sentís que esto te dificultó el conseguir trab...                                                 No
# ¿A qué eventos de tecnología asististe en el úl...                                           nerdeala
# Cantidad de empleados                                                                       1001-2000
# Actividad principal                                                                  Otras industrias
# ¿La recomendás como un buen lugar para trabajar?                                                    3
# ¿Cómo calificás las políticas de diversidad e i...                                                  3
# ¿A cuántos kilómetros de tu casa queda la oficina?                                                 20
# Beneficios extra                                    Abono de celular y/o Internet, Horarios flexib...
# ¿Cuáles considerás que son las mejores empresas...                                                NaN
# e(salary)                                                                                      178790
# pifie                                                                                         12.7531

# %%
df.shape
# Out:
# (5766, 48)

# %%
(df['Salario mensual BRUTO (en tu moneda local)'] < df['Salario mensual NETO (en tu moneda local)']).sum()
# Out:
# 107

# %%
df = df[(df['Salario mensual BRUTO (en tu moneda local)'] >= df['Salario mensual NETO (en tu moneda local)']) | df['Salario mensual NETO (en tu moneda local)'].isna()]

# %%
df.shape
# Out:
# (5659, 48)

# %%
cross_val_score(estimator=Model(**best), X=df, y=df['Salario mensual BRUTO (en tu moneda local)'], cv=5).mean()
# Out:
# 0.514812466090502

# %%
kf = KFold(n_splits=5, shuffle=True, random_state=99)
kf_models = []
for train_index, test_index in kf.split(df):
    model = Model().fit(df.iloc[train_index], df.iloc[train_index]['Salario mensual BRUTO (en tu moneda local)'])
    df.loc[df.index[test_index], 'e(salary)'] = model.predict(df.iloc[test_index])
    kf_models.append(model)

# %%
with open('.kf-cache', 'wb') as f:
    pickle.dump([kf, kf_models], f)

# %%
df['pifie'] = ((df['Salario mensual BRUTO (en tu moneda local)'] - df['e(salary)']).apply(np.abs) / df['Salario mensual BRUTO (en tu moneda local)'])

# %%
df.sort_values(by='pifie').tail().T
# Out:
#                                                                                                  3187  \
# Me identifico                                                                                  Hombre
# Tengo                                                                                              40
# Dónde estás trabajando                                                Ciudad Autónoma de Buenos Aires
# Años de experiencia                                                                                10
# Años en la empresa actual                                                                           4
# Años en el puesto actual                                                                            4
# ¿Gente a cargo?                                                                                     0
# Nivel de estudios alcanzado                                                             Universitario
# Estado                                                                                     Completado
# Carrera                                                       Licenciatura en Sistemas de Información
# Universidad                                                  UAI - Universidad Abierta Interamericana
# Realizaste cursos de especialización                                        Sí, los pagó un empleador
# ¿Contribuís a proyectos open source?                                                               No
# ¿Programás como hobbie?                                                                            No
# Trabajo de                                                                           Technical Writer
# Plataformas                                         Amazon Web Services, Azure, IBM Cloud / Watson...
# Lenguajes de programación                                                          .NET, Java, Python
# Frameworks, herramientas y librerías                                               .NET Core, Node.js
# Bases de datos                                                 IBM Db2, MSSQL, MongoDB, MySQL, Oracle
# QA / Testing                                                                                      NaN
# IDEs                                                                                              NaN
# ¿Qué SO usás en tu laptop/PC para trabajar?                                                     macOS
# ¿Y en tu celular?                                                                                 iOS
# ¿Tenés guardias?                                                                           Sí, activa
# Cuánto cobrás por guardia                                                                           0
# ¿Porcentaje, bruto o neto?                                                    Porcentaje de mi sueldo
# Tipo de contrato                                                                            Freelance
# Salario mensual BRUTO (en tu moneda local)                                                      20000
# Salario mensual NETO (en tu moneda local)                                                       20000
# ¿Qué tan conforme estás con tu sueldo?                                                              3
# Cómo creés que está tu sueldo con respecto al ú...                                                  2
# Recibís algún tipo de bono                                                                         No
# A qué está atado el bono                                                               No recibo bono
# ¿Tuviste ajustes por inflación en 2019?                                                            No
# ¿De qué % fue el ajuste total?                                                                      0
# ¿En qué mes fue el último ajuste?                                                                   1
# ¿Sufriste o presenciaste situaciones de violenc...                                              Jamás
# Orientación sexual                                                                       Heterosexual
# ¿Tenés algún tipo de discapacidad?                                                                NaN
# ¿Sentís que esto te dificultó el conseguir trab...                                                 No
# ¿A qué eventos de tecnología asististe en el úl...                                         Nerdearla
# Cantidad de empleados                                                                         101-200
# Actividad principal                                                                  Otras industrias
# ¿La recomendás como un buen lugar para trabajar?                                                    7
# ¿Cómo calificás las políticas de diversidad e i...                                                  7
# ¿A cuántos kilómetros de tu casa queda la oficina?                                                  7
# Beneficios extra                                        Horarios flexibles, WFH (Trabajar desde casa)
# ¿Cuáles considerás que son las mejores empresas...                                IBM, RedHat, Amazon
# e(salary)                                                                                      115741
# pifie                                                                                         4.78707
#
#                                                                                                  3243  \
# Me identifico                                                                                  Hombre
# Tengo                                                                                              19
# Dónde estás trabajando                                                Ciudad Autónoma de Buenos Aires
# Años de experiencia                                                                                 0
# Años en la empresa actual                                                                           0
# Años en el puesto actual                                                                            0
# ¿Gente a cargo?                                                                                     2
# Nivel de estudios alcanzado                                                                Secundario
# Estado                                                                                     Completado
# Carrera                                                                    Tecnicatura en Informática
# Universidad                                                                                       NaN
# Realizaste cursos de especialización                                          Sí, de forma particular
# ¿Contribuís a proyectos open source?                                                               No
# ¿Programás como hobbie?                                                                            Sí
# Trabajo de                                                                                 Networking
# Plataformas                                                                                     Linux
# Lenguajes de programación                                                            Go, Elixir, Java
# Frameworks, herramientas y librerías                                             jQuery, Rails, Spark
# Bases de datos                                                   Oracle, Percona XtraBackup, Teradata
# QA / Testing                                                                   HP UFT, NUnit, Postman
# IDEs                                                Komodo, RStudio, Sublime Text, Visual Studio Code
# ¿Qué SO usás en tu laptop/PC para trabajar?                                                   Windows
# ¿Y en tu celular?                                                                             Android
# ¿Tenés guardias?                                                                                   No
# Cuánto cobrás por guardia                                                                           0
# ¿Porcentaje, bruto o neto?                                                                       Neto
# Tipo de contrato                                                                            Full-Time
# Salario mensual BRUTO (en tu moneda local)                                                      12000
# Salario mensual NETO (en tu moneda local)                                                       10000
# ¿Qué tan conforme estás con tu sueldo?                                                              2
# Cómo creés que está tu sueldo con respecto al ú...                                                  1
# Recibís algún tipo de bono                                                                         No
# A qué está atado el bono                                                               No recibo bono
# ¿Tuviste ajustes por inflación en 2019?                                                           Uno
# ¿De qué % fue el ajuste total?                                                                     15
# ¿En qué mes fue el último ajuste?                                                                  12
# ¿Sufriste o presenciaste situaciones de violenc...                                              Jamás
# Orientación sexual                                                                       Heterosexual
# ¿Tenés algún tipo de discapacidad?                                                                NaN
# ¿Sentís que esto te dificultó el conseguir trab...                                                NaN
# ¿A qué eventos de tecnología asististe en el úl...                                                NaN
# Cantidad de empleados                                                                            1-10
# Actividad principal                                                       Producto basado en Software
# ¿La recomendás como un buen lugar para trabajar?                                                    7
# ¿Cómo calificás las políticas de diversidad e i...                                                  8
# ¿A cuántos kilómetros de tu casa queda la oficina?                                                  5
# Beneficios extra                                                            Capacitaciones y/o cursos
# ¿Cuáles considerás que son las mejores empresas...                                                NaN
# e(salary)                                                                                     78614.1
# pifie                                                                                         5.55117
#
#                                                                                                  5205  \
# Me identifico                                                                                  Hombre
# Tengo                                                                                              32
# Dónde estás trabajando                                                      Provincia de Buenos Aires
# Años de experiencia                                                                                10
# Años en la empresa actual                                                                           9
# Años en el puesto actual                                                                            8
# ¿Gente a cargo?                                                                                     0
# Nivel de estudios alcanzado                                                                 Terciario
# Estado                                                                                     Completado
# Carrera                                                                          Analista de Sistemas
# Universidad                                                                                       NaN
# Realizaste cursos de especialización                                          Sí, de forma particular
# ¿Contribuís a proyectos open source?                                                               Sí
# ¿Programás como hobbie?                                                                            Sí
# Trabajo de                                                                            Project Manager
# Plataformas                                         Azure, Firebase, HP-UX, Linux, OpenStack, Serv...
# Lenguajes de programación                           .NET, ABAP, ActionScript, Bash/Shell, C++, COB...
# Frameworks, herramientas y librerías                .NET Core, Akka, Bootstrap, CodeIgniter, Cordo...
# Bases de datos                                      Amazon DynamoDB, Amazon Redshift, Amazon RDS/A...
# QA / Testing                                                                   Visual Studio Coded UI
# IDEs                                                                                          Eclipse
# ¿Qué SO usás en tu laptop/PC para trabajar?                                                 GNU/Linux
# ¿Y en tu celular?                                                                             Android
# ¿Tenés guardias?                                                                                   No
# Cuánto cobrás por guardia                                                                           0
# ¿Porcentaje, bruto o neto?                                                    Porcentaje de mi sueldo
# Tipo de contrato                                                                            Full-Time
# Salario mensual BRUTO (en tu moneda local)                                                      15000
# Salario mensual NETO (en tu moneda local)                                                       12000
# ¿Qué tan conforme estás con tu sueldo?                                                              1
# Cómo creés que está tu sueldo con respecto al ú...                                                  1
# Recibís algún tipo de bono                                                                         No
# A qué está atado el bono                                                               No recibo bono
# ¿Tuviste ajustes por inflación en 2019?                                                            No
# ¿De qué % fue el ajuste total?                                                                      0
# ¿En qué mes fue el último ajuste?                                                                   0
# ¿Sufriste o presenciaste situaciones de violenc...                                              Jamás
# Orientación sexual                                                                   Bisexual o queer
# ¿Tenés algún tipo de discapacidad?                                                           Auditiva
# ¿Sentís que esto te dificultó el conseguir trab...                                                 No
# ¿A qué eventos de tecnología asististe en el úl...                                                NaN
# Cantidad de empleados                                                                         101-200
# Actividad principal                                                       Producto basado en Software
# ¿La recomendás como un buen lugar para trabajar?                                                    1
# ¿Cómo calificás las políticas de diversidad e i...                                                  1
# ¿A cuántos kilómetros de tu casa queda la oficina?                                                 25
# Beneficios extra                                                                   Horarios flexibles
# ¿Cuáles considerás que son las mejores empresas...                                                NaN
# e(salary)                                                                                      122069
# pifie                                                                                         7.13794
#
#                                                                                                  4071  \
# Me identifico                                                                                   Mujer
# Tengo                                                                                              26
# Dónde estás trabajando                                                Ciudad Autónoma de Buenos Aires
# Años de experiencia                                                                                 2
# Años en la empresa actual                                                                           2
# Años en el puesto actual                                                                            2
# ¿Gente a cargo?                                                                                     0
# Nivel de estudios alcanzado                                                                 Terciario
# Estado                                                                                     Completado
# Carrera                                                                          Analista Programador
# Universidad                                                                          Escuela Da Vinci
# Realizaste cursos de especialización                                                               No
# ¿Contribuís a proyectos open source?                                                               No
# ¿Programás como hobbie?                                                                            No
# Trabajo de                                                                                  Architect
# Plataformas                                                                                     Linux
# Lenguajes de programación                                                     Bash/Shell, Python, SQL
# Frameworks, herramientas y librerías                                                              NaN
# Bases de datos                                                                                  MySQL
# QA / Testing                                                                                      NaN
# IDEs                                                                                    Nano, Vi, Vim
# ¿Qué SO usás en tu laptop/PC para trabajar?                                                 GNU/Linux
# ¿Y en tu celular?                                                                                 iOS
# ¿Tenés guardias?                                                                                   No
# Cuánto cobrás por guardia                                                                           0
# ¿Porcentaje, bruto o neto?                                                    Porcentaje de mi sueldo
# Tipo de contrato                                                                            Full-Time
# Salario mensual BRUTO (en tu moneda local)                                                      10000
# Salario mensual NETO (en tu moneda local)                                                        9000
# ¿Qué tan conforme estás con tu sueldo?                                                              1
# Cómo creés que está tu sueldo con respecto al ú...                                                  1
# Recibís algún tipo de bono                                                                         No
# A qué está atado el bono                                                               No recibo bono
# ¿Tuviste ajustes por inflación en 2019?                                                            No
# ¿De qué % fue el ajuste total?                                                                      0
# ¿En qué mes fue el último ajuste?                                                                   0
# ¿Sufriste o presenciaste situaciones de violenc...                                              Jamás
# Orientación sexual                                                                                NaN
# ¿Tenés algún tipo de discapacidad?                                                                NaN
# ¿Sentís que esto te dificultó el conseguir trab...                                                NaN
# ¿A qué eventos de tecnología asististe en el úl...                                                NaN
# Cantidad de empleados                                                                        501-1000
# Actividad principal                                                                  Otras industrias
# ¿La recomendás como un buen lugar para trabajar?                                                   10
# ¿Cómo calificás las políticas de diversidad e i...                                                 10
# ¿A cuántos kilómetros de tu casa queda la oficina?                                                  8
# Beneficios extra                                    Capacitaciones y/o cursos, Clases de idiomas, ...
# ¿Cuáles considerás que son las mejores empresas...                                                NaN
# e(salary)                                                                                       81955
# pifie                                                                                          7.1955
#
#                                                                                                  1901
# Me identifico                                                                                  Hombre
# Tengo                                                                                              30
# Dónde estás trabajando                                                Ciudad Autónoma de Buenos Aires
# Años de experiencia                                                                                10
# Años en la empresa actual                                                                           5
# Años en el puesto actual                                                                            2
# ¿Gente a cargo?                                                                                     0
# Nivel de estudios alcanzado                                                                 Terciario
# Estado                                                                                     Incompleto
# Carrera                                                                   Tecnicatura en Programación
# Universidad                                                    UTN - Universidad Tecnológica Nacional
# Realizaste cursos de especialización                Sí, de forma particular, Sí, los pagó un emple...
# ¿Contribuís a proyectos open source?                                                               No
# ¿Programás como hobbie?                                                                            No
# Trabajo de                                                                                QA / Tester
# Plataformas                                                                       Amazon Web Services
# Lenguajes de programación                                                                         SQL
# Frameworks, herramientas y librerías                                                              NaN
# Bases de datos                                                                                    NaN
# QA / Testing                                                                          Postman, SoapUI
# IDEs                                                                                        Notepad++
# ¿Qué SO usás en tu laptop/PC para trabajar?                                                   Windows
# ¿Y en tu celular?                                                                             Android
# ¿Tenés guardias?                                                                                   No
# Cuánto cobrás por guardia                                                                           0
# ¿Porcentaje, bruto o neto?                                                    Porcentaje de mi sueldo
# Tipo de contrato                                                                            Full-Time
# Salario mensual BRUTO (en tu moneda local)                                                      10000
# Salario mensual NETO (en tu moneda local)                                                          77
# ¿Qué tan conforme estás con tu sueldo?                                                              2
# Cómo creés que está tu sueldo con respecto al ú...                                                  2
# Recibís algún tipo de bono                                                                         No
# A qué está atado el bono                                                               No recibo bono
# ¿Tuviste ajustes por inflación en 2019?                                                          Tres
# ¿De qué % fue el ajuste total?                                                                     40
# ¿En qué mes fue el último ajuste?                                                                  10
# ¿Sufriste o presenciaste situaciones de violenc...                                              Jamás
# Orientación sexual                                                                       Heterosexual
# ¿Tenés algún tipo de discapacidad?                                                                NaN
# ¿Sentís que esto te dificultó el conseguir trab...                                                 No
# ¿A qué eventos de tecnología asististe en el úl...                                                NaN
# Cantidad de empleados                                                                        501-1000
# Actividad principal                                     Servicios / Consultoría de Software / Digital
# ¿La recomendás como un buen lugar para trabajar?                                                    8
# ¿Cómo calificás las políticas de diversidad e i...                                                 10
# ¿A cuántos kilómetros de tu casa queda la oficina?                                                 20
# Beneficios extra                                    Capacitaciones y/o cursos, Clases de idiomas, ...
# ¿Cuáles considerás que son las mejores empresas...                                                NaN
# e(salary)                                                                                     82352.7
# pifie                                                                                         7.23527
